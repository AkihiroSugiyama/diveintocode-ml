# %% [markdown]
# ### Mount google drive

# %%
# 自分のマイドライブにマウントする

from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Drive already mounted at /content/drive/; to attempt to forcibly remount, call drive.mount("/content/drive/", force_remount=True).

# %%
# カレントディレクトリの変更

import os

os.chdir('/content/drive/My Drive/')

# カレントディレクトリの取得
print(os.getcwd())
# Out:
# /content/drive/My Drive

# %% [markdown]
# ### Configure kaggle API

# %%
mkdir .kaggle

# %%
# !ls -l -a
# Out:
# total 20
# drwx------ 4 root root 4096 Sep 28 02:33 'Colab Notebooks'
# drwx------ 2 root root 4096 Sep 28 02:33  dataset
# drwx------ 5 root root 4096 Sep 29 01:45  git
# drwx------ 2 root root 4096 Sep 28 02:33  images
# drwx------ 2 root root 4096 Sep 29 01:47  .kaggle

# %%
# !mv '/content/drive/My Drive/kaggle.json' '/content/drive/My Drive/.kaggle/'

# %%
# !pip install kaggle

# %%
# https://www.kaggle.com/　へアクセスし、ログイン後に右上のプロフィール画像をクリック、さらに"My Account"をクリックする
# このサイトの「API」項目にある"Create New API Token"をクリックすると、kaggle.jsonファイルが自動的にダウンロードされる
# ローカルで、kaggle.json（ダウンロードフォルダにあるはず）をエディターで開く。
# このセルの以下のコードにある token = {'username':'***','key':'***'} における「***」部分を、
# ダウンロードしたkaggle.jsonを参照して書き換え、このセルを実行する

import json

token = {"username":"akihirosugiyama","key":"c5feeaf80ac2d092ef05c9c6a2771503"}
with open('/content/drive/My Drive/.kaggle/kaggle.json', 'w') as file:
    json.dump(token, file)

# %%
# !chmod 600 '/content/drive/My Drive/.kaggle/kaggle.json'

# %%
mkdir　/root/.kaggle/

# %%
# !cp -R '/content/drive/My Drive/.kaggle/kaggle.json' '/root/.kaggle/'

# %%
# kaggle APIコマンドが使えるかどうかを確認


# !kaggle competitions list
# Out:
# ...
# ref                                            deadline             category            reward  teamCount  userHasEntered
# ---------------------------------------------  -------------------  ---------------  ---------  ---------  --------------
# contradictory-my-dear-watson                   2030-07-01 23:59:00  Getting Started     Prizes        291           False
# gan-getting-started                            2030-07-01 23:59:00  Getting Started     Prizes        125           False
# tpu-getting-started                            2030-06-03 23:59:00  Getting Started  Knowledge        363           False
# digit-recognizer                               2030-01-01 00:00:00  Getting Started  Knowledge       2384           False
# titanic                                        2030-01-01 00:00:00  Getting Started  Knowledge      17943            True
# house-prices-advanced-regression-techniques    2030-01-01 00:00:00  Getting Started  Knowledge       4737            True
# ...

# %% [markdown]
# ### Download dataset

# %%
# simpsonデータセットのAPIコマンドでデータセットをダウンロードする
# APIコマンドはこちらのサイトを参照。https://www.kaggle.com/c/tgs-salt-identification-challenge/data

# !kaggle competitions download -c tgs-salt-identification-challenge --force
# Out:
# ...
#   0% 0.00/322k [00:00<?, ?B/s]
# 100% 322k/322k [00:00<00:00, 40.8MB/s]
# ...
#   0% 0.00/264k [00:00<?, ?B/s]
# 100% 264k/264k [00:00<00:00, 36.8MB/s]
# ...
#  96% 208M/217M [00:03<00:00, 78.7MB/s]
# 100% 217M/217M [00:03<00:00, 71.6MB/s]
# ...
#   0% 0.00/922k [00:00<?, ?B/s]
# 100% 922k/922k [00:00<00:00, 60.1MB/s]
# ...
#  87% 33.0M/37.9M [00:01<00:00, 15.6MB/s]
# 100% 37.9M/37.9M [00:01<00:00, 35.6MB/s]
# ...
# 100% 163M/163M [00:02<00:00, 33.2MB/s]
# 100% 163M/163M [00:02<00:00, 57.6MB/s]
# ...
#  70% 29.0M/41.4M [00:00<00:00, 17.8MB/s]
# 100% 41.4M/41.4M [00:00<00:00, 53.2MB/s]

# %%
# !unzip /content/drive/'My Drive'/dataset/TGS_Salt_Identification_Challenge/competition_data.zip

# %%
# !unzip /content/drive/'My Drive'/dataset/TGS_Salt_Identification_Challenge/train.zip
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: images/b012e9ebb0.png
#   inflating: images/d3034e7a60.png
#   inflating: images/ae2ef70d51.png
#   inflating: images/1af44a9db0.png
#   inflating: images/41cfd4b320.png
#   inflating: images/853e89d0d3.png
#   inflating: images/2a484baa26.png
#   inflating: images/92e617896e.png
#   inflating: images/b70f0ab0c2.png
#   inflating: images/e8757626a1.png
#   inflating: images/6a3d92ce59.png
#   inflating: images/127ef4105f.png
#   inflating: images/d21012f5c1.png
#   inflating: images/1cb9549d2c.png
#   inflating: images/e030bdae65.png
#   inflating: images/0cf7155eb6.png
#   inflating: images/badb3ea766.png
#   inflating: images/9bd58061d6.png
#   inflating: images/2b1e71c2a3.png
#   inflating: images/28d42de29f.png
#   inflating: images/10833853b3.png
#   inflating: images/ef13247eed.png
#   inflating: images/bce104494c.png
#   inflating: images/c8ce151a18.png
#   inflating: images/302ea1ac81.png
#   inflating: images/59b1bac5d5.png
# ...

# %%
# !unzip /content/drive/'My Drive'/dataset/TGS_Salt_Identification_Challenge/test.zip
# Out:
# ストリーミング出力は最後の 5000 行に切り捨てられました。
#   inflating: images/187ecc32d5.png
#   inflating: images/54538419f5.png
#   inflating: images/93614d4b95.png
#   inflating: images/50a91adce8.png
#   inflating: images/97d23cea10.png
#   inflating: images/ca04c19c0b.png
#   inflating: images/d168218bac.png
#   inflating: images/a670e833a4.png
#   inflating: images/a964a0f499.png
#   inflating: images/371bf59030.png
#   inflating: images/fc74f77bae.png
#   inflating: images/f63dc1e3be.png
#   inflating: images/b807539a5f.png
#   inflating: images/1dfcbf4bca.png
#   inflating: images/a971d2ae53.png
#   inflating: images/4ad823e2d3.png
#   inflating: images/85a9687a4f.png
#   inflating: images/da5b430ecd.png
#   inflating: images/b1a2903d1c.png
#   inflating: images/70958cacd4.png
#   inflating: images/2093e5c98e.png
#   inflating: images/f2c108fd0b.png
#   inflating: images/56b0d83562.png
#   inflating: images/09aa9bde24.png
#   inflating: images/3cb4906b6e.png
#   inflating: images/42bfae680f.png
# ...

# %%
# !unzip /content/drive/'My Drive'/dataset/TGS_Salt_Identification_Challenge/flamingo.zip

# %% [markdown]
# ### Download model

# %%
# !git clone https://github.com/zhixuhao/unet.git
# Out:
# Cloning into 'unet'...
# remote: Enumerating objects: 394, done.
# remote: Total 394 (delta 0), reused 0 (delta 0), pack-reused 394
# Receiving objects: 100% (394/394), 44.92 MiB | 19.31 MiB/s, done.
# Resolving deltas: 100% (79/79), done.
# Checking out files: 100% (253/253), done.

# %%
# !mv /content/drive/'My Drive'/competition_data /content/drive/'My Drive'/git/unet/data/

# %%
cd /content/drive/'My Drive'/git/unet/data/competition_data
# Out:
# /content/drive/My Drive/git/unet/data/competition_data

# %%
ls -l
# Out:
# total 330
# -rw------- 1 root root 329525 Jul 11  2018 depths.csv
# drwx------ 3 root root   4096 Sep 29 01:58 test/
# drwx------ 3 root root   4096 Sep 29 02:06 train/

# %%
cd /content/drive/'My Drive'/dataset/TGS_Salt_Identification_Challenge/
# Out:
# /content/drive/My Drive/dataset/TGS_Salt_Identification_Challenge

# %%
ls -a -l
# Out:
# total 471749
# -rw------- 1 root root 227132081 Sep 29 01:55 competition_data.zip
# -rw------- 1 root root    329525 Sep 29 01:55 depths.csv
# -rw------- 1 root root  43373216 Sep 29 01:55 flamingo.zip
# -rw------- 1 root root    270012 Sep 29 01:55 sample_submission.csv
# -rw------- 1 root root 171262199 Sep 29 01:55 test.zip
# -rw------- 1 root root    943702 Sep 29 01:55 train.csv
# -rw------- 1 root root  39757560 Sep 29 01:55 train.zip

# %% [markdown]
# ### Change Tensorflow and Keras versions

# %%
import tensorflow as tf
tf.__version__
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
# !pip install tensorflow==1.14.0
# Out:
# ...
#      |████████████████████████████████| 109.2MB 101kB/s
# ...
#      |████████████████████████████████| 3.2MB 49.8MB/s
# ...
#      |████████████████████████████████| 491kB 49.6MB/s
# ...
#      |████████████████████████████████| 51kB 8.0MB/s
# ...
#   Found existing installation: tensorboard 2.3.0
#     Uninstalling tensorboard-2.3.0:
#       Successfully uninstalled tensorboard-2.3.0
#   Found existing installation: tensorflow-estimator 2.3.0
#     Uninstalling tensorflow-estimator-2.3.0:
#       Successfully uninstalled tensorflow-estimator-2.3.0
#   Found existing installation: tensorflow 2.3.0
#     Uninstalling tensorflow-2.3.0:
#       Successfully uninstalled tensorflow-2.3.0
# ...

# %%
import keras
keras.__version__
# Out:
# Using TensorFlow backend.
# '2.0.2'

# %%
# !pip install keras==2.0.2
# Out:
# ...
#      |████████████████████████████████| 194kB 5.6MB/s
# ...
#   Created wheel for keras: filename=Keras-2.0.2-cp36-none-any.whl size=228897 sha256=a2acd26bf7ff01d3a59b91113282c46c637fbc64b65b242200982777fec130f2
#   Stored in directory: /root/.cache/pip/wheels/78/38/73/74028957a9c42049a56878c4bb8a2c732c3e205f599fb9b384
# Successfully built keras
# ERROR: textgenrnn 1.4.1 has requirement keras>=2.1.5, but you'll have keras 2.0.2 which is incompatible.
# ...
#   Found existing installation: Keras 2.4.3
#     Uninstalling Keras-2.4.3:
#       Successfully uninstalled Keras-2.4.3
# ...

# %% [markdown]
# tensorflow ver.1 ではgpuを使うには
# tensorflow-gpuをインストールしないといけないっぽい
#
#
# Update 2020<br>
# It seems like tensorflow 2.0+ comes with gpu capabilities therefore pip install tensorflow should be enough
#
# 参照元 [stackoverflow - Tensorflow doesn't seem to see my gpu](https://stackoverflow.com/questions/41402409/tensorflow-doesnt-seem-to-see-my-gpu)

# %%
# !pip install tensorflow-gpu==1.14.0
# Out:
# ...
#      |████████████████████████████████| 377.0MB 43kB/s
# ...

# %%
import tensorflow as tf

# %% [markdown]
# ## 【問題1】学習・推定
# 以下のKeras実装を使用して学習・推定を行ってください。
#
#
# zhixuhao/unet: unet for image segmentation
#
#
# 《GPU環境での学習》
#
#
# 大規模なデータセット、大きなモデルになるため、GPUを使用する必要があります。
#
#
# 《新たなデータセットの適用》
#
#
# 公開されている実装で用意されたものとは異なるデータセットを入力するための準備が必要です。

# %% [markdown]
# 参照元 [trainUnet.ipynb](https://github.com/zhixuhao/unet/blob/master/trainUnet.ipynb)

# %%
import tensorflow as tf
import keras

display(tf.__version__)
display(keras.__version__)
# Out:
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:516: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:517: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# /usr/local/lib/python3.6/dist-packages/tensorflow/python/framework/dtypes.py:518: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %% [markdown]
# ### Make sure to use GPU runtime

# %%
# GPUに接続しているか確認
# !nvidia-smi
# Out:
# Tue Sep 29 08:19:48 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.66       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   55C    P8    12W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# GPUが使えているか確認
tf.test.gpu_device_name()
# Out:
# '/device:GPU:0'

# %% [markdown]
# ### Import external .py libraries

# %%
cd /content/drive/'My Drive'/git/unet/
# Out:
# /content/drive/My Drive/git/unet

# %%
import sys
sys.path.append('/content/drive/My Drive/git/unet')

from model import *
from data import *

# %% [markdown]
# ### Train with data generator

# %%
data_gen_args = dict(rotation_range=0.2,
                    width_shift_range=0.05,
                    height_shift_range=0.05,
                    shear_range=0.05,
                    zoom_range=0.05,
                    horizontal_flip=True,
                    fill_mode='nearest')
myGene = trainGenerator(2,'data/competition_data/train','images','masks',data_gen_args,save_to_dir = None)
model = unet()
model_checkpoint = ModelCheckpoint('unet_salt.hdf5', monitor='loss',verbose=1, save_best_only=True)
model.fit_generator(myGene,steps_per_epoch=300,epochs=4,callbacks=[model_checkpoint])
# Out:
# /content/drive/My Drive/git/unet/model.py:55: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)
# Epoch 1/4
# Found 2771 images belonging to 1 classes.
# Found 4000 images belonging to 1 classes.
# ...
# 300/300 [==============================] - 61s - loss: 0.6906 - acc: 0.7733
# Epoch 2/4
# ...
# 300/300 [==============================] - 54s - loss: 0.6845 - acc: 0.7550
# Epoch 3/4
# ...
# 300/300 [==============================] - 54s - loss: 0.6792 - acc: 0.7558
# Epoch 4/4
# ...
# 300/300 [==============================] - 55s - loss: 0.6755 - acc: 0.7391

# %% [markdown]
# 総epocが１３５０くらいを超えたあたりから、下記エラーが出る。今回はepoch数が超えないように学習を進める。
#
# ValueError: Input arrays should have the same number of samples as target arrays. Found 1 input samples and 2 target samples. site:stackoverflow.com

# %% [markdown]
# ### Train with npy file

# %%
#imgs_train,imgs_mask_train = geneTrainNpy("data/membrane/train/aug/","data/membrane/train/aug/")
#model.fit(imgs_train, imgs_mask_train, batch_size=2, nb_epoch=10, verbose=1,validation_split=0.2, shuffle=True, callbacks=[model_checkpoint])

# %% [markdown]
# ### Test your model and save predicted results

# %%
# !mkdir '/content/drive/My Drive/git/unet/data/competition_data/test/predict'

# %%
test_path = "data/competition_data/test/images"
files = os.listdir(test_path)

# %%
files[-0]
# Out:
# 'dc066ad24e.png'

# %%
len(files)
# Out:
# 18000

# %%
testGene = testGenerator("data/competition_data/test/images", num_image=100)
model = unet(input_size=(256,256,1))
model.load_weights("unet_salt.hdf5")
results = model.predict_generator(testGene,91,verbose=1)
saveResult("data/competition_data/test/images", "data/competition_data/test/predict/",results)
# Out:
# /content/drive/My Drive/git/unet/model.py:55: UserWarning: Update your `Model` call to the Keras 2 API: `Model(inputs=Tensor("in..., outputs=Tensor("co...)`
#   model = Model(input = inputs, output = conv10)
# 91/91 [==============================] - 3s
# Exception in thread Thread-21:
# Traceback (most recent call last):
#   File "/usr/lib/python3.6/threading.py", line 916, in _bootstrap_inner
#     self.run()
#   File "/usr/lib/python3.6/threading.py", line 864, in run
#     self._target(*self._args, **self._kwargs)
#   File "/usr/local/lib/python3.6/dist-packages/keras/engine/training.py", line 606, in data_generator_task
#     generator_output = next(self._generator)
# StopIteration
#
# /content/drive/My Drive/git/unet/data.py:126: UserWarning: data/competition_data/test/predict/predict_dc066ad24e.png is a low contrast image
#   io.imsave(os.path.join(save_path,"predict_%s"%files[i]),img)
# ...

# %% [markdown]
# colabのメモリオーバーで100枚くらいが限界？

# %% [markdown]
# ## 【問題2】コードリーディング
# 論文[1]に目を通した上で、上記実装のコードリーディングを行ってください。

# %% [markdown]
# 参照元　[model.py](https://github.com/zhixuhao/unet/blob/master/model.py)

# %% [markdown]
# - Conv, Conv, MaxPoolingを繰り返す。
# - 最後の２層ははConvの後にDropoutが追加されている（過学習抑制)
# - 出力層：sigmoid
# conv10 = Conv2D(1, 1, activation = 'sigmoid')(conv9)
# - 最適化手法：adam, 損失関数：　バイナリークロスエントロピー
# model.compile(optimizer = Adam(lr = 1e-4), loss = 'binary_crossentropy', metrics = ['accuracy'])
